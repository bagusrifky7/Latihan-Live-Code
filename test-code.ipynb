# %%
# Membuat list kosong
grade_list = []

def masukkan_data():
        name = input("Masukkan nama: ") # input nama
        grade = input("Masukkan nilai: ") # input nilai
        grade_list.append([name, int(grade)])
        print(grade_list)

# %%
while True:
    masukkan_data()
    if
# Out:
#   Cell In[20], line 9
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
name = input("Masukkan nama: ") # input nama
print(name)
# Out:
# 2
